# %% [markdown]
# # STD

# %%
import numpy as np
import pandas as pd
a = [94,93]
np.std(a)
# Out:
# 0.5

# %%
data = pd.read_csv('./Twitter_Twint/Result/Keywords_Trends/Dominican_trends_total.csv')
# data
data = data.drop(columns=['PRI_DOM_date','PRI_DOM_date.1'])
data
# Out:
#         date  PRI_DOM_feliznavidad  PRI_DOM_maddon  PRI_DOM_geishas  \
# 0     6/7/15                     0               0                0
# 1    6/14/15                     0               0                0
# 2    6/21/15                     0               0                0
# 3    6/28/15                     0               0                0
# 4     7/5/15                     0               0                0
# ..       ...                   ...             ...              ...
# 151  4/29/18                     0               0                0
# 152   5/6/18                     0               0                0
# 153  5/13/18                     0               0                0
# 154  5/20/18                     0               0                0
# 155  5/27/18                     0               0                0
#
#      PRI_DOM_29  PRI_DOM_cotillard  PRI_DOM_el especial de  PRI_DOM_paterson  \
# ...

# %%
std_list = []
column_name_list = ["date"]
column_num = data.shape[1]
for i in range(1,column_num):
    column_name = data.columns[i]
    std_value = np.std([i for i in data[column_name].tolist() if i not in [0,100]])
    std_list.append(std_value)
    if std_value > 0 : 
        column_name_list.append(column_name)
# Out:
# /Users/yueqiang/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/yueqiang/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:195: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Users/yueqiang/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# len(column_name_list)
# [i for i in data['PRI_DOM_date'].tolist() if i not in [0,100]]

# %%
result = data[column_name_list]

# %%
result
# Out:
#         date  PRI_DOM_feliznavidad  PRI_DOM_maddon  PRI_DOM_geishas  \
# 0     6/7/15                     0               0                0
# 1    6/14/15                     0               0                0
# 2    6/21/15                     0               0                0
# 3    6/28/15                     0               0                0
# 4     7/5/15                     0               0                0
# ..       ...                   ...             ...              ...
# 151  4/29/18                     0               0                0
# 152   5/6/18                     0               0                0
# 153  5/13/18                     0               0                0
# 154  5/20/18                     0               0                0
# 155  5/27/18                     0               0                0
#
#      PRI_DOM_29  PRI_DOM_cotillard  PRI_DOM_el especial de  PRI_DOM_paterson  \
# ...

# %%
result.to_csv('Dominican_trends_std.csv',index_label=False)

# %% [markdown]
# # Augmented Dickey-Fuller test

# %%
def filter_keywords_by_ADF(path):
    column_name_list = ["date"]
    data = pd.read_csv(path)
    column_name = data.columns[1:]
    for i in range(len(column_name)):
        X = data[column_name[i]].values
        result = adfuller(X)
#         print("Keyword: %s" % column_name[i])
#         print('ADF Statistic: %f' % result[0])
#         print('p-value: %f' % result[1])
#         print('Critical Values:')
#         for key, value in result[4].items():
#             print('\t%s: %.3f' % (key, value))
#         print("Difference of ADF Statistic and Critical Values : %f " % (result[0] - result[4]['5%']))
        diff = result[0] - result[4]['5%']
        if diff < 0:
            column_name_list.append(column_name[i])
    return column_name_list

# %%
path = "Dominican_trends_std.csv"
column_name = filter_keywords_by_ADF(path)
pd.read_csv(path)[column_name]
# Out:
#         date  PRI_DOM_feliznavidad  PRI_DOM_maddon  PRI_DOM_geishas  \
# 0     6/7/15                     0               0                0
# 1    6/14/15                     0               0                0
# 2    6/21/15                     0               0                0
# 3    6/28/15                     0               0                0
# 4     7/5/15                     0               0                0
# ..       ...                   ...             ...              ...
# 151  4/29/18                     0               0                0
# 152   5/6/18                     0               0                0
# 153  5/13/18                     0               0                0
# 154  5/20/18                     0               0                0
# 155  5/27/18                     0               0                0
#
#      PRI_DOM_29  PRI_DOM_cotillard  PRI_DOM_el especial de  PRI_DOM_paterson  \
# ...

# %% [markdown]
# # MARSS

# %%
import rpy2
import rpy2.robjects.packages as rpackages
from rpy2.robjects.vectors import StrVector
from rpy2.robjects.packages import importr

# %%
# utils = rpackages.importr('utils')
# utils.chooseCRANmirror(ind=2)
# # Install packages
# packnames = ("MARSS")
# utils.install_packages(StrVector(packnames))
# Load packages
importr("MARSS")
# Out:
# rpy2.robjects.packages.Package as a <module 'MARSS'>

# %%
import rpy2.robjects as robjects
from rpy2.robjects.lib import grdevices
from rpy2.robjects.vectors import IntVector
from IPython.display import Image, display
graphics = robjects.packages.importr('graphics')

# %%
with grdevices.render_to_bytesio(grdevices.jpeg, width=1024, height=896, res=150) as img:
    graphics.barplot(IntVector((1,3,2,5,4)), ylab="Value")
    
display(Image(data=img.getvalue(), format='jpeg', embed=True))

# %%
import rpy2.robjects.lib.ggplot2 as ggplot2
datasets = robjects.packages.importr('datasets')
mtcars = robjects.packages.data(datasets).fetch('mtcars')['mtcars']
with grdevices.render_to_bytesio(grdevices.png, width=1024, height=896, res=150) as img:
    gp = ggplot2.ggplot(mtcars)
    pp = (
        gp
        + ggplot2.aes_string(x='wt', y='mpg')
        + ggplot2.geom_point(ggplot2.aes_string(colour='qsec'))
        + ggplot2.scale_colour_gradient(low='yellow', high='red')
        + ggplot2.labs(title='Rpy2 ggplot2 MTCARS')
        + ggplot2.theme_bw()
        + ggplot2.theme(**{'panel.grid.major': ggplot2.element_blank(),
                           'panel.grid.minor': ggplot2.element_blank()
        })  
    )
    pp.plot()
display(Image(data=img.getvalue(), format='png', embed=True))
